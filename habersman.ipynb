# %%
import os 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir(r"D:\PYTHON\Dataset")

# %%
da=pd.read_csv("haberman.csv")

# %%
da.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
# to see the no.of rows and no. of columns
print(da.shape)  

# 305 rows and 4 columns
# Out:
# (305, 4)

# %%
# to check the NAN values , Dtype of col. , col_name , memmory usage of data
print(da.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   30      305 non-null    int64
#  1   64      305 non-null    int64
#  2   1       305 non-null    int64
#  3   1.1     305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB
# None

# %%
# for better understanding of data change a columns name in meaningfull words
da =da.rename(columns={"30": "Age", "64": "Age_oper","1": "Nodes", "1.1": "Survival"})
da
# Out:
#      Age  Age_oper  Nodes  Survival
# 0     30        62      3         1
# 1     30        65      0         1
# 2     31        59      2         1
# 3     31        65      4         1
# 4     33        58     10         1
# ..   ...       ...    ...       ...
# 300   75        62      1         1
# 301   76        67      0         1
# 302   77        65      3         1
# 303   78        65      1         2
# 304   83        58      2         2
#
# [305 rows x 4 columns]

# %%
# to check the no. of unique values 
print('"Age" ---- ',da['Age'].nunique())
print('"Age_oper" ---- ',da['Age_oper'].nunique())
print('"Nodes" ---- ',da['Nodes'].nunique())
print('"Survival" ---- ',da['Survival'].nunique())
# Out:
# "Age" ----  49
# "Age_oper" ----  12
# "Nodes" ----  31
# "Survival" ----  2

# %%
#da['Survival'].values   #  -- only two values 1 , 2 , change th dtype
da['Survival']=da['Survival'].astype("category")
da['Survival']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 300    1
# 301    1
# 302    1
# 303    2
# 304    2
# Name: Survival, Length: 305, dtype: category
# Categories (2, int64): [1, 2]

# %%
# from above we also decrease the size of data 
da.info()

# before ---> 9.7kb
# now ----> 7.7 kb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       305 non-null    int64
#  1   Age_oper  305 non-null    int64
#  2   Nodes     305 non-null    int64
#  3   Survival  305 non-null    category
# dtypes: category(1), int64(3)
# memory usage: 7.7 KB

# %%
da.describe()
# Out:
#               Age    Age_oper       Nodes
# count  305.000000  305.000000  305.000000
# mean    52.531148   62.849180    4.036066
# std     10.744024    3.254078    7.199370
# min     30.000000   58.000000    0.000000
# 25%     44.000000   60.000000    0.000000
# 50%     52.000000   63.000000    1.000000
# 75%     61.000000   66.000000    4.000000
# max     83.000000   69.000000   52.000000

# %% [markdown]
# ### Observations:
# * The age of the patients vary from 30 to 83 with the median of 52.
# * The maximum number of nodes observed is 52, around 75% of the patients have less than 4  nodes and around 25% of the patients have no  nodes

# %% [markdown]
# # Univarite
# * Univariate involves the analysis of a single variable

# %%
# to see the no. of people who survived or not and thier percentage 
# here if patient is survived represented by 1 or not survived represented by 2  
op=da['Survival'].unique()
op_c = da['Survival'].value_counts()
op_pct= op_c / len(da.index)*100
opt = pd.concat([op_c, op_pct], axis=1).set_axis(['count', 'pct'], axis=1, inplace=False)
print("no. of data per calssification")
opt
# Out:
# no. of data per calssification
#    count        pct
# 1    224  73.442623
# 2     81  26.557377

# %%
# plot the pie chart 
labels = 'survived', 'not_survived'
survived = len(da[da['Survival']==1])
not_survived = len(da[da['Survival']==2])

details = [survived,not_survived]
explodes = [0.1,0]
colors = ['yellowgreen','red']

plt.pie(details,labels = labels,explode = explodes,colors =colors,autopct = "%0.1f%%",startangle=60, shadow=True)
plt.show()

# %% [markdown]
# # to check the patient survival
# * if(AxillaryNodes≤0)
# * Patient= Long survival
# * else if(AxillaryNodes≥0 && Axillary nodes≤3.5(approx))
# * Patient= Long survival chances are high
# * else if(Axillary nodes ≥3.5)
# * Patient = Short survival

# %%
# maximum nodes in our data 
da.Nodes.max()
# Out:
# 52

# %%
# enter a nodes to check the person survival status 
n=int(input("Enter an node number : "))
if(n<=0):
    print("Long survival")
elif(n > 0 and n <= 4):
    print('Long survival chances are high')
else:
    print("Short survival")
# Out:
# Enter an node number : 2
# Long survival chances are high

# %% [markdown]
# # longest  survival

# %%
plt.hist(l_sur)
plt.title("longest survival")
plt.xlabel("Node")
plt.ylabel("Age category")
# Out:
# Text(0, 0.5, 'Age category')

# %% [markdown]
# # chance to survive

# %%
plt.hist(c_sur)
plt.title("longest survival")
plt.xlabel("Node")
plt.ylabel("Age category")
# Out:
# Text(0, 0.5, 'Age category')

# %% [markdown]
# # short survival

# %%
plt.hist(s_sur)
plt.title("longest survival")
plt.xlabel("Node")
plt.ylabel("Age category")
# Out:
# Text(0, 0.5, 'Age category')

# %%
list(da.columns[:-1])
# Out:
# ['Age', 'Age_oper', 'Nodes']

# %%
for i in list(da.columns[:-1]):
    fg = sns.FacetGrid(da,hue="Survival",size=4).map(sns.distplot,i).add_legend()
    plt.show()
# Out:
# C:\Users\Sahil Prajapati\Anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sahil Prajapati\Anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sahil Prajapati\Anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Multivariate

# %% [markdown]
# ## pair plot

# %%
sns.set_style("dark");
sns.pairplot(da, hue="Survival", size=5);
plt.show()
# Out:
# C:\Users\Sahil Prajapati\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 2-D Scatter Plot

# %%
sns.set_style("darkgrid");
sns.scatterplot(x="Age", y="Age_oper" ,data=da ,hue="Survival")

# %%
# to see nodes present in the age 
sns.scatterplot(x="Age", y="Nodes" ,data=da ,hue="Survival")

# %% [markdown]
# ### observations
# * those patients ar not survived which have more than 4 nodes

# %%
age=da['Age']
age_oper=da['Age_oper']

sns.lineplot(x = age, y = age_oper , data = da)

plt.title("Line Plot", fontsize = 20) # for title
plt.xlabel("Age", fontsize = 15) # label for x-axis
plt.ylabel("Age_oper", fontsize = 15) # label for y-axis
plt.show()

# %%
sur=da['Survival']

plt.figure(figsize = (16,9))
sns.lineplot(x = age, y = age_oper , hue = sur ,color='r')

# %% [markdown]
# # Box plot

# %%
sns.boxplot( x='Age', y='Survival', data=da)   
plt.show()

# %% [markdown]
# ### observation
# * most survival patient age is 43 - 58(approx) during cancer

# %%
sns.boxplot( x='Survival', y='Age_oper', data=da)   
plt.show()

# %%
sns.barplot( x='Survival', y='Nodes', data=da)   
plt.show()

# %% [markdown]
# ### observation
# * only those patients survive who have less than 3 nodes

# %% [markdown]
# ### cdf & pdf
# * The PDF returns the expected probability for observing a value. For discrete data, the PDF is referred to as a Probability Mass Function (PMF). The CDF returns the expected probability for observing a value less than or equal to a given value

# %% [markdown]
# Box-plot with whiskers: another method of visualizing the  1-D scatter plot more intuitivey.
# The Concept of median, percentile, quantile.
# How to draw the box in the box-plot?
# How to draw whiskers: [no standard way] Could use min and max or use other complex statistical techniques.
# IQR like idea.
#
# NOTE: IN the plot below, a technique call inter-quartile range is used in plotting the whiskers.
# Whiskers in the plot below donot correposnd to the min and max values.
#
# Box-plot can be visualized as a PDF on the side-ways.

# %%
# A violin plot combines the benefits of the previous two plots 
#and simplifies them

# Denser regions of the data are fatter, and sparser ones thinner 
#in a violin plot

for i in list(da.columns[:-1]):
    sns.FacetGrid(da, hue="Survival", size=5).map(sns.violinplot,i).add_legend()
    plt.show()
# Out:
# C:\Users\Sahil Prajapati\Anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sahil Prajapati\Anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\Sahil Prajapati\Anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sahil Prajapati\Anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# ...

# %% [markdown]
# # (3.11) Multivariate probability density, contour plot.

# %%
#2D Density plot, contors-plot
sns.jointplot(x="Age_oper", y="Survival", data=da, kind="kde");
plt.show();
